# %% [markdown]
# <a href="https://colab.research.google.com/github/Alahin04/Ejercicio-N5-POO-Resuelto/blob/main/Ejercicio_5_resuelto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ejercicio 5 - Samuel López

import math

#variables
Suma = 0
x = 20
y = 40

#operaciones
Suma = Suma + x

x = x + math.pow(y,2)

Suma = Suma + (x / y)

print(f"El valor de x es : {x}")
print(f"El valor de y es : {y}")
print(f"El valor de la Suma es : {Suma}")
# Out:
# El valor de x es : 1620.0
# El valor de y es : 40
# El valor de la Suma es : 60.5
